# %%
# !pip install keras-unet-collection
# Out:
# Collecting keras-unet-collection
#   Downloading keras_unet_collection-0.1.13-py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 3.1 MB/s
# Installing collected packages: keras-unet-collection
# Successfully installed keras-unet-collection-0.1.13

# %%
import tensorflow as tf
import os
import sys
import numpy as np
import pandas as pd  
from tqdm import tqdm
from itertools import chain
from skimage.io import imread, imshow
from skimage.transform import resize
import random
import matplotlib.pyplot as plt
import time
import tensorflow_hub as hub
from google.colab import drive
from tensorflow.keras.optimizers import Adam
from tensorflow import keras
from keras_unet_collection import models, losses
from datetime import datetime

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#pre-processing and check all images and masks correctly read
IMG_WIDTH = 512
IMG_HEIGHT = 256
IMG_CHANNELS = 1
 
DATA_PATH = '/content/drive/MyDrive/Colab_Notebooks/GP/dataset/training_set/images/' # Training original images
Mask_path1= '/content/drive/MyDrive/Colab_Notebooks/GP/dataset/training_set/segmentation_map/'   # Segmentation Map


seed = 42
random.seed = seed
np.random.seed = seed
 
image_ids = next(os.walk(DATA_PATH))[2]

len(image_ids)
X = np.zeros((len(image_ids), IMG_HEIGHT, IMG_WIDTH), dtype=np.uint8)
Y = np.zeros((len(image_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)

print('resizing training images and masks')
for n, id_ in tqdm(enumerate(image_ids), total=len(image_ids)):
  try:
    path = DATA_PATH 
    img = imread(path+ id_)[:,:]
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X[n] = img
    mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
    for mask_file in next(os.walk(Mask_path1))[2]:
      if mask_file==id_:
        #print(Mask_path1 +  mask_file)
        mask_ = imread(Mask_path1 + mask_file)
        mask_ = np.expand_dims(resize(mask_, (IMG_HEIGHT, IMG_WIDTH), mode='constant',
                                      preserve_range=True), axis=-1)
        mask = np.maximum(mask, mask_)

    Y[n] = mask
  except:
    print('error')

x_train=X 
y_train=Y

print('Done!')

image_x = random.randint(0, len(image_ids))#i added -1 temp
imshow(x_train[image_x])
plt.show()
imshow(np.squeeze(y_train[image_x]))
plt.show()
# Out:
# resizing training images and masks
# 100%|██████████| 379/379 [02:44<00:00,  2.31it/s]
# Done!
# /usr/local/lib/python3.7/dist-packages/skimage/io/_plugins/matplotlib_plugin.py:150: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %%
#test images
TEST_PATH = '/content/drive/MyDrive/Colab_Notebooks/GP/dataset/testing_set/images/'

test_ids = next(os.walk(TEST_PATH))[2]

len(test_ids)
X_test = np.zeros((len(test_ids), IMG_HEIGHT, IMG_WIDTH), dtype=np.uint8)

sizes_test=[]
print('resizing training images')
for n, id_ in tqdm(enumerate(test_ids), total=len(test_ids)):
  path = TEST_PATH 
  img = imread(path+ id_)[:,:]
  sizes_test.append([img.shape[0],img.shape[1]])
  img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
  X_test[n]=img 

#X_test=X 
#y_test=Y
# Out:
# resizing training images
# 100%|██████████| 218/218 [00:51<00:00,  4.27it/s]

# %%
num_labels = 1  #Binary
input_shape = (IMG_HEIGHT,IMG_WIDTH,IMG_CHANNELS)
batch_size = 8

# %%
help(models.unet_plus_2d)
# Out:
# Help on function unet_plus_2d in module keras_unet_collection._model_unet_plus_2d:
#
# unet_plus_2d(input_size, filter_num, n_labels, stack_num_down=2, stack_num_up=2, activation='ReLU', output_activation='Softmax', batch_norm=False, pool=True, unpool=True, deep_supervision=False, backbone=None, weights='imagenet', freeze_backbone=True, freeze_batch_norm=True, name='xnet')
#     U-net++ with an optional ImageNet-trained backbone.
#
#     unet_plus_2d(input_size, filter_num, n_labels, stack_num_down=2, stack_num_up=2,
#                  activation='ReLU', output_activation='Softmax', batch_norm=False, pool=True, unpool=True, deep_supervision=False,
#                  backbone=None, weights='imagenet', freeze_backbone=True, freeze_batch_norm=True, name='xnet')
#
#     ----------
#     Zhou, Z., Siddiquee, M.M.R., Tajbakhsh, N. and Liang, J., 2018. Unet++: A nested u-net architecture
#     for medical image segmentation. In Deep Learning in Medical Image Analysis and Multimodal Learning
#     for Clinical Decision Support (pp. 3-11). Springer, Cham.
#
#     Input
#     ----------
#         input_size: the size/shape of network input, e.g., `(128, 128, 3)`.
#         filter_num: a list that defines the number of filters for each                     down- and upsampling levels. e.g., `[64, 128, 256, 512]`.
#                     The depth is expected as `len(filter_num)`.
#         n_labels: number of output labels.
#         stack_num_down: number of convolutional layers per downsampling level/block.
#         stack_num_up: number of convolutional layers (after concatenation) per upsampling level/block.
#         activation: one of the `tensorflow.keras.layers` or `keras_unet_collection.activations` interfaces, e.g., 'ReLU'.
#         output_activation: one of the `tensorflow.keras.layers` or `keras_unet_collection.activations` interface or 'Sigmoid'.
#                            Default option is 'Softmax'.
#                            if None is received, then linear activation is applied.
#         batch_norm: True for batch normalization.
#         pool: True or 'max' for MaxPooling2D.
#               'ave' for AveragePooling2D.
#               False for strided conv + batch norm + activation.
#         unpool: True or 'bilinear' for Upsampling2D with bilinear interpolation.
#                 'nearest' for Upsampling2D with nearest interpolation.
#                 False for Conv2DTranspose + batch norm + activation.
#         deep_supervision: True for a model that supports deep supervision. Details see Zhou et al. (2018).
#         name: prefix of the created keras model and its layers.
#
#         ---------- (keywords of backbone options) ----------
#         backbone_name: the bakcbone model name. Should be one of the `tensorflow.keras.applications` class.
#                        None (default) means no backbone.
#                        Currently supported backbones are:
#                        (1) VGG16, VGG19
#                        (2) ResNet50, ResNet101, ResNet152
#                        (3) ResNet50V2, ResNet101V2, ResNet152V2
#                        (4) DenseNet121, DenseNet169, DenseNet201
#                        (5) EfficientNetB[0-7]
#         weights: one of None (random initialization), 'imagenet' (pre-training on ImageNet),
#                  or the path to the weights file to be loaded.
#         freeze_backbone: True for a frozen backbone.
#         freeze_batch_norm: False for not freezing batch normalization layers.
#
#     Output
#     ----------
#         model: a keras model.

# %%
model_Unet_plus = models.unet_plus_2d((256, 512, 1), filter_num=[16,32,64, 128, 256], 
                           n_labels=num_labels, 
                           stack_num_down=2, stack_num_up=2, 
                           activation='ReLU', 
                           output_activation='Sigmoid', 
                           batch_norm=True, pool=True, unpool=True, 
                           backbone=None, weights=None, 
                           freeze_backbone=False, freeze_batch_norm=False,
                           name='unet_plus')

model_Unet_plus.compile(loss='binary_crossentropy', optimizer='adam', 
              metrics=['accuracy', losses.dice_coef])

print(model_Unet_plus.summary())
# Out:
# Model: "unet_plus_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 256, 512, 1)]     0
#
#  unet_plus_down0_0 (Conv2D)  (None, 256, 512, 16)      144
#
#  unet_plus_down0_0_bn (Batch  (None, 256, 512, 16)     64
#  Normalization)
#
#  unet_plus_down0_0_activatio  (None, 256, 512, 16)     0
#  n (ReLU)
#
#  unet_plus_down0_1 (Conv2D)  (None, 256, 512, 16)      2304
#
#  unet_plus_down0_1_bn (Batch  (None, 256, 512, 16)     64
#  Normalization)
#
#  unet_plus_down0_1_activatio  (None, 256, 512, 16)     0
#  n (ReLU)
#
#  unet_plus_down1_encode_maxp  (None, 128, 256, 16)     0
#  ool (MaxPooling2D)
#
#  unet_plus_down1_conv_0 (Con  (None, 128, 256, 32)     4608
#  v2D)
#
#  unet_plus_down1_conv_0_bn (  (None, 128, 256, 32)     128
#  BatchNormalization)
#
#  unet_plus_down1_conv_0_acti  (None, 128, 256, 32)     0
#  vation (ReLU)
#
#  unet_plus_down1_conv_1 (Con  (None, 128, 256, 32)     9216
#  v2D)
#
#  unet_plus_down1_conv_1_bn (  (None, 128, 256, 32)     128
#  BatchNormalization)
#
#  unet_plus_down1_conv_1_acti  (None, 128, 256, 32)     0
#  vation (ReLU)
#
#  unet_plus_down2_encode_maxp  (None, 64, 128, 32)      0
#  ool (MaxPooling2D)
#
#  unet_plus_down2_conv_0 (Con  (None, 64, 128, 64)      18432
#  v2D)
#
#  unet_plus_down2_conv_0_bn (  (None, 64, 128, 64)      256
#  BatchNormalization)
#
#  unet_plus_down2_conv_0_acti  (None, 64, 128, 64)      0
#  vation (ReLU)
#
#  unet_plus_down2_conv_1 (Con  (None, 64, 128, 64)      36864
#  v2D)
#
#  unet_plus_down2_conv_1_bn (  (None, 64, 128, 64)      256
#  BatchNormalization)
#
#  unet_plus_down2_conv_1_acti  (None, 64, 128, 64)      0
#  vation (ReLU)
#
#  unet_plus_down3_encode_maxp  (None, 32, 64, 64)       0
#  ool (MaxPooling2D)
#
#  unet_plus_down3_conv_0 (Con  (None, 32, 64, 128)      73728
#  v2D)
#
#  unet_plus_down3_conv_0_bn (  (None, 32, 64, 128)      512
#  BatchNormalization)
#
#  unet_plus_down3_conv_0_acti  (None, 32, 64, 128)      0
#  vation (ReLU)
#
#  unet_plus_down3_conv_1 (Con  (None, 32, 64, 128)      147456
#  v2D)
#
#  unet_plus_down3_conv_1_bn (  (None, 32, 64, 128)      512
#  BatchNormalization)
#
#  unet_plus_down3_conv_1_acti  (None, 32, 64, 128)      0
#  vation (ReLU)
#
#  unet_plus_down4_encode_maxp  (None, 16, 32, 128)      0
#  ool (MaxPooling2D)
#
#  unet_plus_down4_conv_0 (Con  (None, 16, 32, 256)      294912
#  v2D)
#
#  unet_plus_down4_conv_0_bn (  (None, 16, 32, 256)      1024
#  BatchNormalization)
#
#  unet_plus_down4_conv_0_acti  (None, 16, 32, 256)      0
#  vation (ReLU)
#
#  unet_plus_down4_conv_1 (Con  (None, 16, 32, 256)      589824
#  v2D)
#
#  unet_plus_down4_conv_1_bn (  (None, 16, 32, 256)      1024
#  BatchNormalization)
#
#  unet_plus_down4_conv_1_acti  (None, 16, 32, 256)      0
#  vation (ReLU)
#
#  unet_plus_up0_from3_decode_  (None, 32, 64, 256)      0
#  unpool (UpSampling2D)
#
#  unet_plus_up0_from3_conv_be  (None, 32, 64, 128)      294912
#  fore_concat_0 (Conv2D)
#
#  unet_plus_up0_from3_conv_be  (None, 32, 64, 128)      512
#  fore_concat_0_bn (BatchNorm
#  alization)
#
#  unet_plus_up0_from3_conv_be  (None, 32, 64, 128)      0
#  fore_concat_0_activation (R
#  eLU)
#
#  unet_plus_up0_from3_conv_af  (None, 32, 64, 128)      147456
#  ter_concat_0 (Conv2D)
#
#  unet_plus_up0_from3_conv_af  (None, 32, 64, 128)      512
#  ter_concat_0_bn (BatchNorma
#  lization)
#
#  unet_plus_up0_from3_conv_af  (None, 32, 64, 128)      0
#  ter_concat_0_activation (Re
#  LU)
#
#  unet_plus_up0_from3_conv_af  (None, 32, 64, 128)      147456
#  ter_concat_1 (Conv2D)
#
#  unet_plus_up0_from3_conv_af  (None, 32, 64, 128)      512
#  ter_concat_1_bn (BatchNorma
#  lization)
#
#  unet_plus_up0_from3_conv_af  (None, 32, 64, 128)      0
#  ter_concat_1_activation (Re
#  LU)
#
#  unet_plus_up1_from2_decode_  (None, 64, 128, 128)     0
#  unpool (UpSampling2D)
#
#  unet_plus_up1_from2_conv_be  (None, 64, 128, 64)      73728
#  fore_concat_0 (Conv2D)
#
#  unet_plus_up1_from2_conv_be  (None, 64, 128, 64)      256
#  fore_concat_0_bn (BatchNorm
#  alization)
#
#  unet_plus_up1_from2_conv_be  (None, 64, 128, 64)      0
#  fore_concat_0_activation (R
#  eLU)
#
#  unet_plus_up1_from2_conv_af  (None, 64, 128, 64)      36864
#  ter_concat_0 (Conv2D)
#
#  unet_plus_up1_from2_conv_af  (None, 64, 128, 64)      256
#  ter_concat_0_bn (BatchNorma
#  lization)
#
#  unet_plus_up1_from2_conv_af  (None, 64, 128, 64)      0
#  ter_concat_0_activation (Re
#  LU)
#
#  unet_plus_up1_from2_conv_af  (None, 64, 128, 64)      36864
#  ter_concat_1 (Conv2D)
#
#  unet_plus_up1_from2_conv_af  (None, 64, 128, 64)      256
#  ter_concat_1_bn (BatchNorma
#  lization)
#
#  unet_plus_up1_from2_conv_af  (None, 64, 128, 64)      0
#  ter_concat_1_activation (Re
#  LU)
#
#  unet_plus_up2_from1_decode_  (None, 128, 256, 64)     0
#  unpool (UpSampling2D)
#
#  unet_plus_up2_from1_conv_be  (None, 128, 256, 32)     18432
#  fore_concat_0 (Conv2D)
#
#  unet_plus_up2_from1_conv_be  (None, 128, 256, 32)     128
#  fore_concat_0_bn (BatchNorm
#  alization)
#
#  unet_plus_up2_from1_conv_be  (None, 128, 256, 32)     0
#  fore_concat_0_activation (R
#  eLU)
#
#  unet_plus_up2_from1_conv_af  (None, 128, 256, 32)     9216
#  ter_concat_0 (Conv2D)
#
#  unet_plus_up2_from1_conv_af  (None, 128, 256, 32)     128
#  ter_concat_0_bn (BatchNorma
#  lization)
#
#  unet_plus_up2_from1_conv_af  (None, 128, 256, 32)     0
#  ter_concat_0_activation (Re
#  LU)
#
#  unet_plus_up2_from1_conv_af  (None, 128, 256, 32)     9216
#  ter_concat_1 (Conv2D)
#
#  unet_plus_up2_from1_conv_af  (None, 128, 256, 32)     128
#  ter_concat_1_bn (BatchNorma
#  lization)
#
#  unet_plus_up2_from1_conv_af  (None, 128, 256, 32)     0
#  ter_concat_1_activation (Re
#  LU)
#
#  unet_plus_up3_from0_decode_  (None, 256, 512, 32)     0
#  unpool (UpSampling2D)
#
#  unet_plus_up3_from0_conv_be  (None, 256, 512, 16)     4608
#  fore_concat_0 (Conv2D)
#
#  unet_plus_up3_from0_conv_be  (None, 256, 512, 16)     64
#  fore_concat_0_bn (BatchNorm
#  alization)
#
#  unet_plus_up3_from0_conv_be  (None, 256, 512, 16)     0
#  fore_concat_0_activation (R
#  eLU)
#
#  unet_plus_up3_from0_conv_af  (None, 256, 512, 16)     2304
#  ter_concat_0 (Conv2D)
#
#  unet_plus_up3_from0_conv_af  (None, 256, 512, 16)     64
#  ter_concat_0_bn (BatchNorma
#  lization)
#
#  unet_plus_up3_from0_conv_af  (None, 256, 512, 16)     0
#  ter_concat_0_activation (Re
#  LU)
#
#  unet_plus_up3_from0_conv_af  (None, 256, 512, 16)     2304
#  ter_concat_1 (Conv2D)
#
#  unet_plus_up3_from0_conv_af  (None, 256, 512, 16)     64
#  ter_concat_1_bn (BatchNorma
#  lization)
#
#  unet_plus_up3_from0_conv_af  (None, 256, 512, 16)     0
#  ter_concat_1_activation (Re
#  LU)
#
#  unet_plus_output (Conv2D)   (None, 256, 512, 1)       17
#
#  unet_plus_output_activation  (None, 256, 512, 1)      0
#   (Activation)
#
# =================================================================
# Total params: 1,967,713
# Trainable params: 1,964,289
# Non-trainable params: 3,424
# _________________________________________________________________
# None

# %%
start2 = datetime.now() 
callbacks= [tf.keras.callbacks.EarlyStopping(patience=5, monitor='val_loss')]
Unet_plus_history = model_Unet_plus.fit(x_train, y_train, 
                    verbose=1,
                    batch_size = batch_size,
                    validation_split=0.1, 
                    shuffle=False,
                    epochs=50, callbacks=callbacks)

stop2 = datetime.now()
#Execution time of the model 
execution_time_Unet_plus = stop2-start2
print("UNet plus execution time is: ", execution_time_Unet_plus)
# Out:
# Epoch 1/50
# 43/43 [==============================] - 46s 712ms/step - loss: 0.3573 - accuracy: 0.9626 - dice_coef: 0.0129 - val_loss: 0.5168 - val_accuracy: 0.9942 - val_dice_coef: 0.0120
# Epoch 2/50
# 43/43 [==============================] - 25s 570ms/step - loss: 0.2067 - accuracy: 0.9943 - dice_coef: 0.0212 - val_loss: 0.4305 - val_accuracy: 0.9942 - val_dice_coef: 0.0145
# Epoch 3/50
# 43/43 [==============================] - 25s 571ms/step - loss: 0.1539 - accuracy: 0.9964 - dice_coef: 0.0376 - val_loss: 0.3080 - val_accuracy: 0.9941 - val_dice_coef: 0.0147
# Epoch 4/50
# 43/43 [==============================] - 25s 572ms/step - loss: 0.1174 - accuracy: 0.9972 - dice_coef: 0.0579 - val_loss: 0.1797 - val_accuracy: 0.9945 - val_dice_coef: 0.0202
# Epoch 33/50
# 43/43 [==============================] - 25s 570ms/step - loss: 0.0049 - accuracy: 0.9990 - dice_coef: 0.7104 - val_loss: 0.0063 - val_accuracy: 0.9985 - val_dice_coef: 0.6840
# Epoch 34/50
# 43/43 [==============================] - 24s 570ms/step - loss: 0.0049 - accuracy: 0.9990 - dice_coef: 0.7156 - val_loss: 0.0059 - val_accuracy: 0.9985 - val_dice_coef: 0.7011
# Epoch 35/50
# 43/43 [==============================] - 24s 570ms/step - loss: 0.0050 - accuracy: 0.9988 - dice_coef: 0.7120 - val_loss: 0.0094 - val_accuracy: 0.9973 - val_dice_coef: 0.6231
# Epoch 36/50
# 43/43 [==============================] - 24s 570ms/step - loss: 0.0050 - accuracy: 0.9988 - dice_coef: 0.7113 - val_loss: 0.0060 - val_accuracy: 0.9983 - val_dice_coef: 0.7156
# Epoch 37/50
# 43/43 [==============================] - 24s 570ms/step - loss: 0.0043 - accuracy: 0.9991 - dice_coef: 0.7421 - val_loss: 0.0071 - val_accuracy: 0.9981 - val_dice_coef: 0.6849
# Epoch 38/50
# 43/43 [==============================] - 24s 570ms/step - loss: 0.0041 - accuracy: 0.9991 - dice_coef: 0.7551 - val_loss: 0.0082 - val_accuracy: 0.9978 - val_dice_coef: 0.6497
# Epoch 39/50
# 43/43 [==============================] - 25s 570ms/step - loss: 0.0042 - accuracy: 0.9990 - dice_coef: 0.7509 - val_loss: 0.0070 - val_accuracy: 0.9982 - val_dice_coef: 0.6833
# UNet plus execution time is:  0:16:17.987144

# %%
t = time.time()
my_keras_model_filepath = '3rdm_UNet_plus_50epochs.h5'.format(int(t))
print(my_keras_model_filepath)
model_Unet_plus.save(my_keras_model_filepath)
# Out:
# 3rdm_UNet_plus_50epochs.h5

# %%
unet_plus_history_df = pd.DataFrame(Unet_plus_history.history)

# %%
with open('unet_plus_history_df.csv', mode='w') as f:
    unet_plus_history_df.to_csv(f)

# %%
history = Unet_plus_history

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['dice_coef']
#acc = history.history['accuracy']
val_acc = history.history['val_dice_coef']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training Dice')
plt.plot(epochs, val_acc, 'r', label='Validation Dice')
plt.title('Training and validation Dice')
plt.xlabel('Epochs')
plt.ylabel('Dice')
plt.legend()
plt.show()

# %%
model = model_Unet_plus

# %%
idx = random.randint(0, len(x_train))
preds_train = model.predict(x_train[:int(x_train.shape[0]*0.9)], verbose=1)
preds_val = model.predict(x_train[int(x_train.shape[0]*0.9):], verbose=1)
preds_test = model.predict(X_test, verbose=1)

preds_train_t = (preds_train > 0.5).astype(np.uint8)
preds_val_t = (preds_val > 0.5).astype(np.uint8)
preds_test_t = (preds_test > 0.5).astype(np.uint8)
# Out:
# 11/11 [==============================] - 16s 928ms/step
# 2/2 [==============================] - 1s 522ms/step
# 7/7 [==============================] - 9s 1s/step

# %%
ix = random.randint(0, len(preds_test_t))
imshow(X_test[ix])
plt.show()
imshow(np.squeeze(preds_test_t[ix]))
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/skimage/io/_plugins/matplotlib_plugin.py:150: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %% [markdown]
# #Support References:
#
#
# *   https://github.com/bnsreenu/python_for_microscopists/blob/master/227_mito_segm_using_models_from_Keras_Unet_collection.py
# *   https://pypi.org/project/keras-unet-collection/
# *   https://github.com/yingkaisha/keras-unet-collection/blob/main/examples/user_guide_models.ipynb
# *   https://www.youtube.com/watch?v=ZoJuhRbzEiM
